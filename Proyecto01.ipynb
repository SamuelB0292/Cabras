# %% [markdown]
# <a href="https://colab.research.google.com/github/SamuelB0292/Cabras/blob/main/Proyecto01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proyecto 01
# ## mostrar informacion al usuario
#
#
# * print()

# %%
print("Semana de la practica")
# Out:
# Semana de la practica

# %%
input("escriba su clave: ")
input("cual es el mejor lenguaje de programacion: ")
# Out:
# escriba su clave: 1234
# cual es el mejor lenguaje de programacion: python
# 'python'

# %% [markdown]
# Almacenando variables

# %%
proyecto = "Mi Primer Proyecto con Python"

# %%
print(proyecto)
# Out:
# Mi Primer Proyecto con Python

# %%
print(Proyecto)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_755/1355834820.py in <cell line: 0>()
# ----> 1 print(Proyecto)
#
# NameError: name 'Proyecto' is not defined

# %%
numero = 10

# %%
print(numero)
# Out:
# 10

# %% [markdown]
# Mezclando todos los conceptos aprendidos

# %%
proyecto = input("Escriba la descripcion del proyecto: ")
horas_estimadas = input("Escriba las horas estimadas para el proyecto: ")
valor_hora = input("¿Cual es el valor de la hora trabajada?")
plazo_estimado = input("Escribir cuanto tiempo estima que va a tomar el proyecto: ")
# Out:
# Escriba la descripcion del proyecto: Analisis financiero
# Escriba las horas estimadas para el proyecto: 20
# ¿Cual es el valor de la hora trabajada?20
# Escribir cuanto tiempo estima que va a tomar el proyecto: 2 meses

# %%
print(proyecto)
print(horas_estimadas)
print(valor_hora)
print(plazo_estimado)
# Out:
# Analisis financiero
# 20
# 20
# 2 meses

# %% [markdown]
# ## Calculos con python

# %%
print(10 + 2)
print(124 - 24)
print(13 * 2)
print(100 / 2)
# Out:
# 12
# 100
# 26
# 50.0

# %% [markdown]
# ## Calculando el valor total del proyecto

# %%
valor_total = int(horas_estimadas) * int(valor_hora)

# %%
print(valor_total)
# Out:
# 400

# %% [markdown]
# ## Generando archivos PDF del presupuesto
#
#
# * Crear archivo pdf
# * Definir el tipo de letra
# * Guardar el entregable

# %%
# !pip install fpdf
# Out:
# Collecting fpdf
#   Downloading fpdf-1.7.2.tar.gz (39 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: fpdf
#   Building wheel for fpdf (setup.py) ... done
#   Created wheel for fpdf: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40761 sha256=500ad9e6e327a5afc115cf92d492490f8001de7a71bdaa1ebfe0d22e66ff452a
#   Stored in directory: /root/.cache/pip/wheels/aa/da/11/a3189f34ddc13c26a2d0f329eac46b728c7f31c39e4dc26243
# Successfully built fpdf
# Installing collected packages: fpdf
# Successfully installed fpdf-1.7.2

# %%
from fpdf import FPDF

# %%
pdf = FPDF()

pdf.add_page()
pdf.set_font("Arial")

pdf.image("Template.png", 0, 0)
pdf.text(115, 145, proyecto)
pdf.text(115, 160, horas_estimadas)
pdf.text(115, 175, valor_hora)
pdf.text(115, 190, plazo_estimado)
pdf.text(115, 205, str(valor_total))

pdf.output("Presupuesto.pdf")
# Out:
# ''
